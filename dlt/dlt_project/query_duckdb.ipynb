# %%
import duckdb

conn = duckdb.connect('bvg_pipeline.duckdb')

conn.execute("SELECT * FROM bvg_data.arrivals LIMIT 5").fetch_df()
# Out:
#                  trip_id stop__type   stop__id  \
# 0   1|24073|6|86|3032025       stop  900110007
# 1  1|44106|24|86|3032025       stop  900110007
# 2  1|61479|37|86|3032025       stop  900110007
# 3   1|24073|1|86|3032025       stop  900110007
# 4  1|44180|24|86|3032025       stop  900110007
#
#                                    stop__name stop__location__type  \
# 0  Schönhauser Allee/Bornholmer Str. (Berlin)             location
# 1  Schönhauser Allee/Bornholmer Str. (Berlin)             location
# 2  Schönhauser Allee/Bornholmer Str. (Berlin)             location
# 3  Schönhauser Allee/Bornholmer Str. (Berlin)             location
# 4  Schönhauser Allee/Bornholmer Str. (Berlin)             location
#
#   stop__location__id  stop__location__latitude  stop__location__longitude  \
# 0          900110007                 52.553761                  13.414611
# 1          900110007                 52.553761                  13.414611
# ...

# %%
conn.close()
