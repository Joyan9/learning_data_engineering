# %% [markdown]
# # Pagination, Authentication and dlt Cofiguration

# %% [markdown]
# ## Pagination
# - It is used to limit how much data is sent at once via an API
# - If an endpoint supports the `per_page` query parameter then you can decide how many results you want to process at a time

# %%
import requests

# Github provides two parameters
# per_page - results per page
# page - page number to retreive results from

response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.links
# Out:
# {'next': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=2',
#   'rel': 'next'},
#  'last': {'url': 'https://api.github.com/organizations/89419010/events?per_page=10&page=29',
#   'rel': 'last'}}

# %% [markdown]
# ### dlt RESTClient
# - dlt has a helper to handle pagination and to manage repetitive tasks such as
#     - authentication
#     - query parameter handling
#     - pagination

# %%
from dlt.sources.helpers.rest_client import RESTClient
client = RESTClient(base_url="https://api.github.com")

i = 0
for page in client.paginate("orgs/dlt-hub/events"):
    if i < 5: # print only first 5 pages
        print(page)
        i+=1
# Out:
# [{'id': '46859268478', 'type': 'WatchEvent', 'actor': {'id': 3657750, 'login': 'marcodelpin', 'display_login': 'marcodelpin', 'gravatar_id': '', 'url': 'https://api.github.com/users/marcodelpin', 'avatar_url': 'https://avatars.githubusercontent.com/u/3657750?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'started'}, 'public': True, 'created_at': '2025-02-23T08:48:57Z', 'org': {'id': 89419010, 'login': 'dlt-hub', 'gravatar_id': '', 'url': 'https://api.github.com/orgs/dlt-hub', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}, {'id': '46859109665', 'type': 'PushEvent', 'actor': {'id': 98139823, 'login': 'dat-a-man', 'display_login': 'dat-a-man', 'gravatar_id': '', 'url': 'https://api.github.com/users/dat-a-man', 'avatar_url': 'https://avatars.githubusercontent.com/u/98139823?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'repository_id': 452221115, 'push_id': 22807525352, 'size': 11, 'distinct_size': 3, 'ref': 'refs/heads/docs/data-security-and-encryption-measures', 'head': '4c6adad0418210b2ee6d0e70ed9fd27ab9228bf4', 'before': 'd3c60076fda97cb110499aec88a5fe8a528dbfbc', 'commits': [{'sha': '9184a2935c0c2e1b7e3bbdcd71e80bba76985d73', 'author': {'email': '31050507+gregorywaynepower@users.noreply.github.com', 'name': 'Gregory Power'}, 'message': 'update minimum supported Python version installation.md (#2332)\n\n* update minimum supported Python version installation.md\n\n- Python 3.9 is the minimum supported version of Python\n\n* increase upper bound of python version', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/9184a2935c0c2e1b7e3bbdcd71e80bba76985d73'}, {'sha': '11361d9867da1dbbc385480eeb588f2f33eb70e9', 'author': {'email': 'rudolfix@rudolfix.org', 'name': 'rudolfix'}, 'message': 'rollbacks state migration (#2321)\n\n* bumps dlt to version 1.7.0\n\n* keeps pipeline state engine at 4 as change is backward compatible', 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/11361d9867da1dbbc385480eeb588f2f33eb70e9'}, {'sha': '37518877a2bb64b874776ab1019108cc7301d753', 'author': {'email': 'adrian.brudaru@gmail.com', 'name': 'adrianbr'}, 'message': "Orchestra docs (#2237) (#2333)\n\n* fix links (#1977)\n\n* Adding Orchestra Docs Section\n\n* Updated the sidebar to include new documentation and standardized snippet titles (e.g., renamed python to py and yml to yaml) to align with the site's naming conventions.\n\n* Update docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-orchestra.md\n\n\n\n* Update docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-orchestra.md\n\n\n\n* Update docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-orchestra.md\n\n\n\n* Update docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-orchestra.md\n\n\n\n* Update docs/website/docs/walkthroughs/deploy-a-pipeline/deploy-with-orchestra.md\n\n\n\n---------\n\nCo-authored-by: Hugo Lu <127905842+hugolu-1@users.noreply.github.com>\nCo-authored-by: rudolfix <rudolfix@rudolfix.org>\nCo-authored-by: David Scharf <shrps@posteo.net>\nCo-authored-by: dat-a-man <98139823+dat-a-man@users.noreply.github.com>\nCo-authored-by: Alena Astrakhantseva <alena@dlthub.com>", 'distinct': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt/commits/37518877a2bb64b874776ab1019108cc7301d753'}, {'sha': '6bf7c8b3ced4457565c3b1c975b620937dfb3516', 'author': {'email': '32450038+akelad@users.noreply.github.com', 'name': 'Akela Drissner-Schmid'}, 'message': "Add dlt plus docs (#2285)\n\n* create initial dlt+ docs structure\n\n* add sources/destinations\n\n* add ecosystem\n\n* add installation and reference\n\n* fix links\n\n* fix some typos\n\n* adding section Core Concepts\n\n* update intro\n\n* fixing snippet linting errors\n\n* fix snippet\n\n* rename folder to plus, change sidebar ordering\n\n* docs: update sidebar CSS for dlt+ se ...
# [{'id': '46814773343', 'type': 'PullRequestReviewEvent', 'actor': {'id': 1155738, 'login': 'sh-rp', 'display_login': 'sh-rp', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'review': {'id': 2632705728, 'node_id': 'PRR_kwDOGvRYu86c6-bA', 'user': {'login': 'sh-rp', 'id': 1155738, 'node_id': 'MDQ6VXNlcjExNTU3Mzg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'html_url': 'https://github.com/sh-rp', 'followers_url': 'https://api.github.com/users/sh-rp/followers', 'following_url': 'https://api.github.com/users/sh-rp/following{/other_user}', 'gists_url': 'https://api.github.com/users/sh-rp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sh-rp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sh-rp/subscriptions', 'organizations_url': 'https://api.github.com/users/sh-rp/orgs', 'repos_url': 'https://api.github.com/users/sh-rp/repos', 'events_url': 'https://api.github.com/users/sh-rp/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sh-rp/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': None, 'commit_id': '8795cc38941796910cc42ac810b566d256874ff6', 'submitted_at': '2025-02-21T10:55:40Z', 'state': 'approved', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2324#pullrequestreview-2632705728', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2324', 'author_association': 'COLLABORATOR', '_links': {'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2324#pullrequestreview-2632705728'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2324'}}}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2324', 'id': 2341827088, 'node_id': 'PR_kwDOGvRYu86LlXIQ', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2324', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2324.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2324.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2324', 'number': 2324, 'state': 'open', 'locked': False, 'title': 'Docs: remove comments from the shell code blocks', 'user': {'login': 'burnash', 'id': 264674, 'node_id': 'MDQ6VXNlcjI2NDY3NA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/264674?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/burnash', 'html_url': 'https://github.com/burnash', 'followers_url': 'https://api.github.com/users/burnash/followers', 'following_url': 'https://api.github.com/users/burnash/following{/other_user}', 'gists_url': 'https://api.github.com/users/burnash/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/burnash/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/burnash/subscriptions', 'organizations_url': 'https://api.github.com/users/burnash/orgs', 'repos_url': 'https://api.github.com/users/burnash/repos', 'events_url': 'https://api.github.com/users/burnash/events{/privacy}', 'received_events_url': 'https://api.github.com/users/burnash/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'Makes shell commands directly copyable by moving comments into the docs text.', 'created_at': '2025-02-18T11:49:01Z', 'updated_at': '2025-02-21T10:55:40Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': '55e45624e88c932155dc3919191d285e93140df0', 'assignee': None, 'assignees': [], 'requested_reviewers': [], 'requested_teams': [], 'labels': [{'id': 3767923856, 'node_id': 'LA_kwDOGvRYu87glfSQ', 'url': 'https://api.github.com/repos/dlt-hub/dlt/labels/documentation', 'name': 'documentation', 'color': '0075ca', 'default': True, 'description': 'Improvements or additions to documentation'}], 'milestone': None, 'd ...
# [{'id': '46770902651', 'type': 'PullRequestEvent', 'actor': {'id': 101302295, 'login': 'stantsvek', 'display_login': 'stantsvek', 'gravatar_id': '', 'url': 'https://api.github.com/users/stantsvek', 'avatar_url': 'https://avatars.githubusercontent.com/u/101302295?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'opened', 'number': 2337, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2337', 'id': 2346739577, 'node_id': 'PR_kwDOGvRYu86L4Gd5', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2337', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2337.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2337.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2337', 'number': 2337, 'state': 'open', 'locked': False, 'title': 'Docs/dlt plus custom', 'user': {'login': 'stantsvek', 'id': 101302295, 'node_id': 'U_kgDOBgnAFw', 'avatar_url': 'https://avatars.githubusercontent.com/u/101302295?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/stantsvek', 'html_url': 'https://github.com/stantsvek', 'followers_url': 'https://api.github.com/users/stantsvek/followers', 'following_url': 'https://api.github.com/users/stantsvek/following{/other_user}', 'gists_url': 'https://api.github.com/users/stantsvek/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/stantsvek/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/stantsvek/subscriptions', 'organizations_url': 'https://api.github.com/users/stantsvek/orgs', 'repos_url': 'https://api.github.com/users/stantsvek/repos', 'events_url': 'https://api.github.com/users/stantsvek/events{/privacy}', 'received_events_url': 'https://api.github.com/users/stantsvek/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': '### Description\r\nAdd dlt+ logo inside breadcrumbs and custom admonition before H1 for every DLT Plus page using [Swizzling](https://docusaurus.io/docs/2.x/swizzling#what-is-safe-to-swizzle)\r\n\r\n![image](https://github.com/user-attachments/assets/a1f3dd5a-4f39-4cef-8bbc-0690f8c8df7b)\r\n', 'created_at': '2025-02-20T10:31:42Z', 'updated_at': '2025-02-20T10:31:42Z', 'closed_at': None, 'merged_at': None, 'merge_commit_sha': None, 'assignee': None, 'assignees': [], 'requested_reviewers': [{'login': 'burnash', 'id': 264674, 'node_id': 'MDQ6VXNlcjI2NDY3NA==', 'avatar_url': 'https://avatars.githubusercontent.com/u/264674?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/burnash', 'html_url': 'https://github.com/burnash', 'followers_url': 'https://api.github.com/users/burnash/followers', 'following_url': 'https://api.github.com/users/burnash/following{/other_user}', 'gists_url': 'https://api.github.com/users/burnash/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/burnash/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/burnash/subscriptions', 'organizations_url': 'https://api.github.com/users/burnash/orgs', 'repos_url': 'https://api.github.com/users/burnash/repos', 'events_url': 'https://api.github.com/users/burnash/events{/privacy}', 'received_events_url': 'https://api.github.com/users/burnash/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}], 'requested_teams': [], 'labels': [], 'milestone': None, 'draft': False, 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2337/commits', 'review_comments_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2337/comments', 'review_comment_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/comments{/number}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2337/comments', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dlt/statuses/4c8cca5a852bc41584e752fd5dedd8a96d160ed6', 'head': {'label': 'dlt-hub:docs/dlt-plus-custom', 'ref': 'docs/dlt-plus-custom', 'sha': '4c8cca5a852bc41584e752fd5dedd8a96d160ed6', 'user': {'login': 'dlt-hu ...
# [{'id': '46737286034', 'type': 'PullRequestReviewEvent', 'actor': {'id': 68975210, 'login': 'zilto', 'display_login': 'zilto', 'gravatar_id': '', 'url': 'https://api.github.com/users/zilto', 'avatar_url': 'https://avatars.githubusercontent.com/u/68975210?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'review': {'id': 2627098158, 'node_id': 'PRR_kwDOGvRYu86cllYu', 'user': {'login': 'zilto', 'id': 68975210, 'node_id': 'MDQ6VXNlcjY4OTc1MjEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/68975210?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/zilto', 'html_url': 'https://github.com/zilto', 'followers_url': 'https://api.github.com/users/zilto/followers', 'following_url': 'https://api.github.com/users/zilto/following{/other_user}', 'gists_url': 'https://api.github.com/users/zilto/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/zilto/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/zilto/subscriptions', 'organizations_url': 'https://api.github.com/users/zilto/orgs', 'repos_url': 'https://api.github.com/users/zilto/repos', 'events_url': 'https://api.github.com/users/zilto/events{/privacy}', 'received_events_url': 'https://api.github.com/users/zilto/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': None, 'commit_id': 'c20ef0339e0ea38df4cee38a557a6f064399f1ce', 'submitted_at': '2025-02-19T15:00:30Z', 'state': 'commented', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2295#pullrequestreview-2627098158', 'pull_request_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2295', 'author_association': 'COLLABORATOR', '_links': {'html': {'href': 'https://github.com/dlt-hub/dlt/pull/2295#pullrequestreview-2627098158'}, 'pull_request': {'href': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2295'}}}, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2295', 'id': 2332446880, 'node_id': 'PR_kwDOGvRYu86LBlCg', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2295', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2295.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2295.patch', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2295', 'number': 2295, 'state': 'open', 'locked': False, 'title': 'Improved `"decimal"` to `pyarrow` conversion', 'user': {'login': 'zilto', 'id': 68975210, 'node_id': 'MDQ6VXNlcjY4OTc1MjEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/68975210?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/zilto', 'html_url': 'https://github.com/zilto', 'followers_url': 'https://api.github.com/users/zilto/followers', 'following_url': 'https://api.github.com/users/zilto/following{/other_user}', 'gists_url': 'https://api.github.com/users/zilto/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/zilto/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/zilto/subscriptions', 'organizations_url': 'https://api.github.com/users/zilto/orgs', 'repos_url': 'https://api.github.com/users/zilto/repos', 'events_url': 'https://api.github.com/users/zilto/events{/privacy}', 'received_events_url': 'https://api.github.com/users/zilto/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'body': 'Better errors for decimal conversion to pyarrow and helpful messages. \r\n\r\n## Related issues\r\n#2224 This might not fix their error, will need more info to repro database-specific issues.\r\n\r\nThe problem from the original author seems to be solvable with current dlt `precision` and `scale` hints when `data_type="decimal"`([reference](https://dlthub.com/docs/general-usage/schema/#tables-and-columns)). Catching the `pyarrow` exception and adding a helpful message should helpful future users.\r\n\r\nLinking #2273 because it touches the same code path. Having pyarrow infer types as default would likely also solve this issue\r\n\r\n# ...
# [{'id': '46696466465', 'type': 'IssueCommentEvent', 'actor': {'id': 40209326, 'login': 'netlify[bot]', 'display_login': 'netlify', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify[bot]', 'avatar_url': 'https://avatars.githubusercontent.com/u/40209326?'}, 'repo': {'id': 452221115, 'name': 'dlt-hub/dlt', 'url': 'https://api.github.com/repos/dlt-hub/dlt'}, 'payload': {'action': 'created', 'issue': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330', 'repository_url': 'https://api.github.com/repos/dlt-hub/dlt', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330/labels{/name}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330/comments', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330/events', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2330', 'id': 2860938017, 'node_id': 'PR_kwDOGvRYu86Ln9JU', 'number': 2330, 'title': 'small improvements to cli docs generator', 'user': {'login': 'sh-rp', 'id': 1155738, 'node_id': 'MDQ6VXNlcjExNTU3Mzg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1155738?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/sh-rp', 'html_url': 'https://github.com/sh-rp', 'followers_url': 'https://api.github.com/users/sh-rp/followers', 'following_url': 'https://api.github.com/users/sh-rp/following{/other_user}', 'gists_url': 'https://api.github.com/users/sh-rp/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/sh-rp/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/sh-rp/subscriptions', 'organizations_url': 'https://api.github.com/users/sh-rp/orgs', 'repos_url': 'https://api.github.com/users/sh-rp/repos', 'events_url': 'https://api.github.com/users/sh-rp/events{/privacy}', 'received_events_url': 'https://api.github.com/users/sh-rp/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2025-02-18T16:09:21Z', 'updated_at': '2025-02-18T16:10:14Z', 'closed_at': None, 'author_association': 'COLLABORATOR', 'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0}, 'active_lock_reason': None, 'draft': True, 'pull_request': {'url': 'https://api.github.com/repos/dlt-hub/dlt/pulls/2330', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2330', 'diff_url': 'https://github.com/dlt-hub/dlt/pull/2330.diff', 'patch_url': 'https://github.com/dlt-hub/dlt/pull/2330.patch', 'merged_at': None}, 'body': '<!--\r\nThank you for submitting a pull request! Please provide a brief description of your changes below.\r\n-->\r\n### Description\r\nMake cli docs generating more stable. This does not change the output of the current cli setup, but makes the generator more forgiving when helpstrings are missing.', 'reactions': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330/timeline', 'performed_via_github_app': None, 'state_reason': None}, 'comment': {'url': 'https://api.github.com/repos/dlt-hub/dlt/issues/comments/2666175810', 'html_url': 'https://github.com/dlt-hub/dlt/pull/2330#issuecomment-2666175810', 'issue_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/2330', 'id': 2666175810, 'node_id': 'IC_kwDOGvRYu86e6p1C', 'user': {'login': 'netlify[bot]', 'id': 40209326, 'node_id': 'MDM6Qm90NDAyMDkzMjY=', 'avatar_url': 'https://avatars.githubusercontent.com/in/13473?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/netlify%5Bbot%5D', 'html_url': 'https://github.com/apps/netlify', 'followers_url': 'https://api.github.com/users/netlify%5Bbot%5D/followers', 'following_url': 'https://api.github.com/users/netlify%5Bbot%5D/following{/other_user}', 'gists_url': 'https://api.github.com/users/netlify%5Bbot%5D/gists{/gist ...

# %% [markdown]
# There are different types of paginations, in the above code dlt automatically inferred the type but we can specify it as well
#
# - JSONLinkPaginator - link to the next page is included in the JSON response.
# - HeaderLinkPaginator - link to the next page is included in the response headers.
# - OffsetPaginator - pagination based on offset and limit query parameters.
# - PageNumberPaginator - pagination based on page numbers.
# - JSONResponseCursorPaginator - pagination based on a cursor in the JSON response.
# - HeaderCursorPaginator - pagination based on a cursor in the response headers.

# %%
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

client = RESTClient(
    base_url="https://api.github.com",
    paginator=HeaderLinkPaginator()
)

# %% [markdown]
# ### Exercise 1: Pagination with RESTClient
# Question: What type of pagination should we use for the GitHub API?

# %%
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
print(response.headers)
# Out:
# {'Date': 'Sun, 23 Feb 2025 09:08:52 GMT', 'Server': 'Varnish', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': "default-src 'none'; style-src 'unsafe-inline'", 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-RateLimit-Used, X-RateLimit-Resource, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Content-Type': 'application/json; charset=utf-8', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'X-GitHub-Media-Type': 'github.v3; format=json', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1740304296', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '60', 'Content-Length': '278', 'X-GitHub-Request-Id': '43C1:158BC3:50680A8:53E9151:67BAE5A4'}

# %% [markdown]
# The header contains `Link` showing the next page, so GitHub uses HeaderLinkPaginator
#
# ```
# {'Date': 'Sun, 23 Feb 2025 09:09:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"b1c22a97c4cacc94cff289841fb952e9b6c9293f7838d5a87900d5e1ae651c97"', 'Last-Modified': 'Sun, 23 Feb 2025 08:48:57 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/organizations/89419010/events?per_page=10&page=2>; rel="next", <https://api.github.com/organizations/89419010/events?per_page=10&page=29>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1740305371', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'C8B6:3C37A6:1340157:2706F30:67BAE5CB'}
# ```

# %% [markdown]
# ## Authentication

# %%
import os

github_token = os.getenv("GITHUB_TOKEN")

print(github_token)
# Out:
# None
