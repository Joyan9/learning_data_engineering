# %% [markdown]
# # Pagination, Authentication and dlt Cofiguration

# %% [markdown]
# ## Pagination
# - It is used to limit how much data is sent at once via an API
# - If an endpoint supports the `per_page` query parameter then you can decide how many results you want to process at a time

# %%
import requests

# Github provides two parameters
# per_page - results per page
# page - page number to retreive results from

response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
response.links
# Out:
# {}

# %% [markdown]
# ### dlt RESTClient
# - dlt has a helper to handle pagination and to manage repetitive tasks such as
#     - authentication
#     - query parameter handling
#     - pagination

# %%
from dlt.sources.helpers.rest_client import RESTClient
client = RESTClient(base_url="https://api.github.com")

i = 0
for page in client.paginate("orgs/dlt-hub/events"):
    if i < 5: # print only first 5 pages
        print(page)
        i+=1
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 client = RESTClient(base_url="https://api.github.com")
#       4 i = 0
# ----> 5 for page in client.paginate("orgs/dlt-hub/events"):
#       6     if i < 5: # print only first 5 pages
#       7         print(page)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\dlt\sources\helpers\rest_client\client.py:224, in RESTClient.paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, **kwargs)
#     222 while True:
#     223     try:
# --> 224         response = self._send_request(request, **kwargs)
#     225     except IgnoreResponseException:
#     226         break
#
# File ~\AppData\Roaming\Python\Python312\site-packages\dlt\sources\helpers\rest_client\client.py:140, in RESTClient._send_request(self, request, **kwargs)
#     131 send_kwargs = self.session.merge_environment_settings(
#     132     prepared_request.url,
#     133     kwargs.pop("proxies", {}),
#    (...)
#     136     kwargs.pop("cert", None),
#     137 )
#     139 send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 140 return self.session.send(prepared_request, **send_kwargs)
#
# File c:\Python312\Lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Python312\Lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Python312\Lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File c:\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Python312\Lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\dlt\sources\helpers\requests\session.py:61, in Session.send(self, request, **kwargs)
#      59 def send(self, request, **kwargs):  # type: ignore[no-untyped-def]
#      60     kwargs.setdefault("timeout", self.timeout)
# ---> 61     return super().send(request, **kwargs)
#
# File c:\Python312\Lib\site-packages\requests\sessions.py:710, in Session.send(self, request, **kwargs)
#     707 r.elapsed = timedelta(seconds=elapsed)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#     713 if r.history:
#     714
#     715     # If the hooks create history then we want those cookies too
#
# File c:\Python312\Lib\site-packages\requests\hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      28     hooks = [hooks]
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#      32         hook_data = _hook_data
#
# File ~\AppData\Roaming\Python\Python312\site-packages\dlt\sources\helpers\rest_client\client.py:315, in raise_for_status(response, *args, **kwargs)
#     314 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 315     response.raise_for_status()
#
# File c:\Python312\Lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: rate limit exceeded for url: https://api.github.com/orgs/dlt-hub/events

# %% [markdown]
# There are different types of paginations, in the above code dlt automatically inferred the type but we can specify it as well
#
# - JSONLinkPaginator - link to the next page is included in the JSON response.
# - HeaderLinkPaginator - link to the next page is included in the response headers.
# - OffsetPaginator - pagination based on offset and limit query parameters.
# - PageNumberPaginator - pagination based on page numbers.
# - JSONResponseCursorPaginator - pagination based on a cursor in the JSON response.
# - HeaderCursorPaginator - pagination based on a cursor in the response headers.

# %%
from dlt.sources.helpers.rest_client.paginators import HeaderLinkPaginator

client = RESTClient(
    base_url="https://api.github.com",
    paginator=HeaderLinkPaginator()
)

# %% [markdown]
# ### Exercise 1: Pagination with RESTClient
# Question: What type of pagination should we use for the GitHub API?

# %%
response = requests.get("https://api.github.com/orgs/dlt-hub/events?per_page=10&page=1")
print(response.headers)
# Out:
# {'Date': 'Sun, 23 Feb 2025 09:08:52 GMT', 'Server': 'Varnish', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': "default-src 'none'; style-src 'unsafe-inline'", 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-RateLimit-Used, X-RateLimit-Resource, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, Deprecation, Sunset', 'Content-Type': 'application/json; charset=utf-8', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'X-GitHub-Media-Type': 'github.v3; format=json', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1740304296', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '60', 'Content-Length': '278', 'X-GitHub-Request-Id': '43C1:158BC3:50680A8:53E9151:67BAE5A4'}

# %% [markdown]
# The header contains `Link` showing the next page, so GitHub uses HeaderLinkPaginator
#
# ```
# {'Date': 'Sun, 23 Feb 2025 09:09:31 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"b1c22a97c4cacc94cff289841fb952e9b6c9293f7838d5a87900d5e1ae651c97"', 'Last-Modified': 'Sun, 23 Feb 2025 08:48:57 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/organizations/89419010/events?per_page=10&page=2>; rel="next", <https://api.github.com/organizations/89419010/events?per_page=10&page=29>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '0', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'Server': 'github.com', 'Accept-Ranges': 'bytes', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1740305371', 'X-RateLimit-Resource': 'core', 'X-RateLimit-Used': '1', 'Transfer-Encoding': 'chunked', 'X-GitHub-Request-Id': 'C8B6:3C37A6:1340157:2706F30:67BAE5CB'}
# ```

# %% [markdown]
# ## Authentication

# %%
import os

github_token = os.getenv("GITHUB_TOKEN")

if github_token:
    print("GitHub token loaded successfully.")
else:
    print("GitHub token not found. Check your environment variables.")
# Out:
# GitHub token loaded successfully.

# %%
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth

client = RESTClient(
    base_url="https://api.github.com",
    auth=BearerTokenAuth(github_token)
)

i = 0
for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
    if i < 5: # print only first 5 pages
        print(page)
        i+=1
# Out:
# [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login ...
# [{'login': 'jankatins', 'id': 890156, 'node_id': 'MDQ6VXNlcjg5MDE1Ng==', 'avatar_url': 'https://avatars.githubusercontent.com/u/890156?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jankatins', 'html_url': 'https://github.com/jankatins', 'followers_url': 'https://api.github.com/users/jankatins/followers', 'following_url': 'https://api.github.com/users/jankatins/following{/other_user}', 'gists_url': 'https://api.github.com/users/jankatins/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jankatins/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jankatins/subscriptions', 'organizations_url': 'https://api.github.com/users/jankatins/orgs', 'repos_url': 'https://api.github.com/users/jankatins/repos', 'events_url': 'https://api.github.com/users/jankatins/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jankatins/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Tafkas', 'id': 34058, 'node_id': 'MDQ6VXNlcjM0MDU4', 'avatar_url': 'https://avatars.githubusercontent.com/u/34058?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Tafkas', 'html_url': 'https://github.com/Tafkas', 'followers_url': 'https://api.github.com/users/Tafkas/followers', 'following_url': 'https://api.github.com/users/Tafkas/following{/other_user}', 'gists_url': 'https://api.github.com/users/Tafkas/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Tafkas/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Tafkas/subscriptions', 'organizations_url': 'https://api.github.com/users/Tafkas/orgs', 'repos_url': 'https://api.github.com/users/Tafkas/repos', 'events_url': 'https://api.github.com/users/Tafkas/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Tafkas/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'chris-park', 'id': 58880657, 'node_id': 'MDQ6VXNlcjU4ODgwNjU3', 'avatar_url': 'https://avatars.githubusercontent.com/u/58880657?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/chris-park', 'html_url': 'https://github.com/chris-park', 'followers_url': 'https://api.github.com/users/chris-park/followers', 'following_url': 'https://api.github.com/users/chris-park/following{/other_user}', 'gists_url': 'https://api.github.com/users/chris-park/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/chris-park/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/chris-park/subscriptions', 'organizations_url': 'https://api.github.com/users/chris-park/orgs', 'repos_url': 'https://api.github.com/users/chris-park/repos', 'events_url': 'https://api.github.com/users/chris-park/events{/privacy}', 'received_events_url': 'https://api.github.com/users/chris-park/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'ddeveloperr', 'id': 10800686, 'node_id': 'MDQ6VXNlcjEwODAwNjg2', 'avatar_url': 'https://avatars.githubusercontent.com/u/10800686?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ddeveloperr', 'html_url': 'https://github.com/ddeveloperr', 'followers_url': 'https://api.github.com/users/ddeveloperr/followers', 'following_url': 'https://api.github.com/users/ddeveloperr/following{/other_user}', 'gists_url': 'https://api.github.com/users/ddeveloperr/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ddeveloperr/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ddeveloperr/subscriptions', 'organizations_url': 'https://api.github.com/users/ddeveloperr/orgs', 'repos_url': 'https://api.github.com/users/ddeveloperr/repos', 'events_url': 'https://api.github.com/users/ddeveloperr/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ddeveloperr/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jpmmcneill', 'id': 55981540, 'node_id': 'MDQ6VXNlcjU1OTgxNTQw', 'a ...
# [{'login': 'z3z1ma', 'id': 41213451, 'node_id': 'MDQ6VXNlcjQxMjEzNDUx', 'avatar_url': 'https://avatars.githubusercontent.com/u/41213451?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/z3z1ma', 'html_url': 'https://github.com/z3z1ma', 'followers_url': 'https://api.github.com/users/z3z1ma/followers', 'following_url': 'https://api.github.com/users/z3z1ma/following{/other_user}', 'gists_url': 'https://api.github.com/users/z3z1ma/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/z3z1ma/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/z3z1ma/subscriptions', 'organizations_url': 'https://api.github.com/users/z3z1ma/orgs', 'repos_url': 'https://api.github.com/users/z3z1ma/repos', 'events_url': 'https://api.github.com/users/z3z1ma/events{/privacy}', 'received_events_url': 'https://api.github.com/users/z3z1ma/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'shimonymittal', 'id': 95504257, 'node_id': 'U_kgDOBbFHgQ', 'avatar_url': 'https://avatars.githubusercontent.com/u/95504257?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/shimonymittal', 'html_url': 'https://github.com/shimonymittal', 'followers_url': 'https://api.github.com/users/shimonymittal/followers', 'following_url': 'https://api.github.com/users/shimonymittal/following{/other_user}', 'gists_url': 'https://api.github.com/users/shimonymittal/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/shimonymittal/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/shimonymittal/subscriptions', 'organizations_url': 'https://api.github.com/users/shimonymittal/orgs', 'repos_url': 'https://api.github.com/users/shimonymittal/repos', 'events_url': 'https://api.github.com/users/shimonymittal/events{/privacy}', 'received_events_url': 'https://api.github.com/users/shimonymittal/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'livioso', 'id': 1672198, 'node_id': 'MDQ6VXNlcjE2NzIxOTg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1672198?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/livioso', 'html_url': 'https://github.com/livioso', 'followers_url': 'https://api.github.com/users/livioso/followers', 'following_url': 'https://api.github.com/users/livioso/following{/other_user}', 'gists_url': 'https://api.github.com/users/livioso/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/livioso/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/livioso/subscriptions', 'organizations_url': 'https://api.github.com/users/livioso/orgs', 'repos_url': 'https://api.github.com/users/livioso/repos', 'events_url': 'https://api.github.com/users/livioso/events{/privacy}', 'received_events_url': 'https://api.github.com/users/livioso/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tungbq', 'id': 85242618, 'node_id': 'MDQ6VXNlcjg1MjQyNjE4', 'avatar_url': 'https://avatars.githubusercontent.com/u/85242618?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tungbq', 'html_url': 'https://github.com/tungbq', 'followers_url': 'https://api.github.com/users/tungbq/followers', 'following_url': 'https://api.github.com/users/tungbq/following{/other_user}', 'gists_url': 'https://api.github.com/users/tungbq/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tungbq/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tungbq/subscriptions', 'organizations_url': 'https://api.github.com/users/tungbq/orgs', 'repos_url': 'https://api.github.com/users/tungbq/repos', 'events_url': 'https://api.github.com/users/tungbq/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tungbq/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'VincenzoGalante', 'id': 79586031, 'node_id': 'MDQ6VXNlcjc5NTg2MDMx', 'avatar_url': 'https://avatars.githubuser ...
# [{'login': 'yliapis', 'id': 14884413, 'node_id': 'MDQ6VXNlcjE0ODg0NDEz', 'avatar_url': 'https://avatars.githubusercontent.com/u/14884413?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/yliapis', 'html_url': 'https://github.com/yliapis', 'followers_url': 'https://api.github.com/users/yliapis/followers', 'following_url': 'https://api.github.com/users/yliapis/following{/other_user}', 'gists_url': 'https://api.github.com/users/yliapis/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/yliapis/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/yliapis/subscriptions', 'organizations_url': 'https://api.github.com/users/yliapis/orgs', 'repos_url': 'https://api.github.com/users/yliapis/repos', 'events_url': 'https://api.github.com/users/yliapis/events{/privacy}', 'received_events_url': 'https://api.github.com/users/yliapis/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'thisisdope', 'id': 32782533, 'node_id': 'MDQ6VXNlcjMyNzgyNTMz', 'avatar_url': 'https://avatars.githubusercontent.com/u/32782533?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/thisisdope', 'html_url': 'https://github.com/thisisdope', 'followers_url': 'https://api.github.com/users/thisisdope/followers', 'following_url': 'https://api.github.com/users/thisisdope/following{/other_user}', 'gists_url': 'https://api.github.com/users/thisisdope/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/thisisdope/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/thisisdope/subscriptions', 'organizations_url': 'https://api.github.com/users/thisisdope/orgs', 'repos_url': 'https://api.github.com/users/thisisdope/repos', 'events_url': 'https://api.github.com/users/thisisdope/events{/privacy}', 'received_events_url': 'https://api.github.com/users/thisisdope/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'tconbeer', 'id': 705906, 'node_id': 'MDQ6VXNlcjcwNTkwNg==', 'avatar_url': 'https://avatars.githubusercontent.com/u/705906?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tconbeer', 'html_url': 'https://github.com/tconbeer', 'followers_url': 'https://api.github.com/users/tconbeer/followers', 'following_url': 'https://api.github.com/users/tconbeer/following{/other_user}', 'gists_url': 'https://api.github.com/users/tconbeer/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tconbeer/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tconbeer/subscriptions', 'organizations_url': 'https://api.github.com/users/tconbeer/orgs', 'repos_url': 'https://api.github.com/users/tconbeer/repos', 'events_url': 'https://api.github.com/users/tconbeer/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tconbeer/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'davidharting', 'id': 6146772, 'node_id': 'MDQ6VXNlcjYxNDY3NzI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6146772?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/davidharting', 'html_url': 'https://github.com/davidharting', 'followers_url': 'https://api.github.com/users/davidharting/followers', 'following_url': 'https://api.github.com/users/davidharting/following{/other_user}', 'gists_url': 'https://api.github.com/users/davidharting/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/davidharting/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/davidharting/subscriptions', 'organizations_url': 'https://api.github.com/users/davidharting/orgs', 'repos_url': 'https://api.github.com/users/davidharting/repos', 'events_url': 'https://api.github.com/users/davidharting/events{/privacy}', 'received_events_url': 'https://api.github.com/users/davidharting/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'kwigley', 'id': 9877221, 'node_id': 'MDQ6VXNlc ...
# [{'login': 'mrnitrate', 'id': 1325392, 'node_id': 'MDQ6VXNlcjEzMjUzOTI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/1325392?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mrnitrate', 'html_url': 'https://github.com/mrnitrate', 'followers_url': 'https://api.github.com/users/mrnitrate/followers', 'following_url': 'https://api.github.com/users/mrnitrate/following{/other_user}', 'gists_url': 'https://api.github.com/users/mrnitrate/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mrnitrate/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mrnitrate/subscriptions', 'organizations_url': 'https://api.github.com/users/mrnitrate/orgs', 'repos_url': 'https://api.github.com/users/mrnitrate/repos', 'events_url': 'https://api.github.com/users/mrnitrate/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mrnitrate/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'unarmedcivilian', 'id': 8530446, 'node_id': 'MDQ6VXNlcjg1MzA0NDY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8530446?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/unarmedcivilian', 'html_url': 'https://github.com/unarmedcivilian', 'followers_url': 'https://api.github.com/users/unarmedcivilian/followers', 'following_url': 'https://api.github.com/users/unarmedcivilian/following{/other_user}', 'gists_url': 'https://api.github.com/users/unarmedcivilian/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/unarmedcivilian/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/unarmedcivilian/subscriptions', 'organizations_url': 'https://api.github.com/users/unarmedcivilian/orgs', 'repos_url': 'https://api.github.com/users/unarmedcivilian/repos', 'events_url': 'https://api.github.com/users/unarmedcivilian/events{/privacy}', 'received_events_url': 'https://api.github.com/users/unarmedcivilian/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'abhilashchowdhary', 'id': 18218120, 'node_id': 'MDQ6VXNlcjE4MjE4MTIw', 'avatar_url': 'https://avatars.githubusercontent.com/u/18218120?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/abhilashchowdhary', 'html_url': 'https://github.com/abhilashchowdhary', 'followers_url': 'https://api.github.com/users/abhilashchowdhary/followers', 'following_url': 'https://api.github.com/users/abhilashchowdhary/following{/other_user}', 'gists_url': 'https://api.github.com/users/abhilashchowdhary/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/abhilashchowdhary/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/abhilashchowdhary/subscriptions', 'organizations_url': 'https://api.github.com/users/abhilashchowdhary/orgs', 'repos_url': 'https://api.github.com/users/abhilashchowdhary/repos', 'events_url': 'https://api.github.com/users/abhilashchowdhary/events{/privacy}', 'received_events_url': 'https://api.github.com/users/abhilashchowdhary/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jckail', 'id': 13952435, 'node_id': 'MDQ6VXNlcjEzOTUyNDM1', 'avatar_url': 'https://avatars.githubusercontent.com/u/13952435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jckail', 'html_url': 'https://github.com/jckail', 'followers_url': 'https://api.github.com/users/jckail/followers', 'following_url': 'https://api.github.com/users/jckail/following{/other_user}', 'gists_url': 'https://api.github.com/users/jckail/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jckail/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jckail/subscriptions', 'organizations_url': 'https://api.github.com/users/jckail/orgs', 'repos_url': 'https://api.github.com/users/jckail/repos', 'events_url': 'https://api.github.com/users/jckail/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jckail/received_events', ' ...

# %% [markdown]
# ## dlt Configuration and Secrets
# - Configurations are non-senstive, define behaviour of pipeline like setting file paths, database hosts, timeouts, API URLs, and performance settings.
# - Secrets are sensitive - passwords, API keys, auth tokens, these should never be hard-coded
#     - These can be set up in various ways:
#         - Environment variables
#         - Within code using dlt.secrets and dlt.config
#         - Configuration files (secrets.toml and config.toml)

# %%
import dlt
import os
from dlt.sources.helpers import requests
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth
import toml
# Load the secrets file
secrets = toml.load(r"C:\Users\HP\OneDrive\Desktop\Data Engg\dlt\secrets.toml")  # Adjust the path if needed

# method 1
#dlt.secrets['github_token'] = os.getenv('GITHUB_TOKEN')

# method 2
dlt.secrets['github_token'] = secrets.get("GITHUB_TOKEN")

@dlt.source
def github_source():
    client = RESTClient(
        base_url='https://api.github.com',
        auth=BearerTokenAuth(os.getenv('GITHUB_TOKEN'))
    )

    @dlt.resource # if no table naem specified it will use the function name
    def github_events():
        for page in client.paginate("orgs/dlt-hub/events"):
            yield from page

    @dlt.resource
    def github_stargazers():
        for page in client.paginate("repos/dlt-hub/dlt/stargazers"):
            yield from page

    return github_events, github_stargazers

# %%
# define a new pipeline
pipeline = dlt.pipeline(pipeline_name="github_pipeline", destination="duckdb", dataset_name="github.db")

# run the pipeline with the new resource
load_info = pipeline.run(github_source())
print(load_info)
# Out:
# 2025-02-23 11:15:06,032|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:06,032|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,101|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,102|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,275|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,275|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,676|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,677|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,684|[WARNING]|26972|14972|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,687|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,688|[WARNING]|26972|14972|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,689|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,695|[WARNING]|26972|9608|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,698|[WARNING]|26972|9608|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,698|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,701|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,705|[WARNING]|26972|22780|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,707|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,709|[WARNING]|26972|22780|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,710|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,716|[WARNING]|26972|25104|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,719|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,719|[WARNING]|26972|25104|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,722|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,728|[WARNING]|26972|13744|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,731|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,732|[WARNING]|26972|13744|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,733|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,739|[WARNING]|26972|4208|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,742|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,745|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,743|[WARNING]|26972|4208|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,750|[WARNING]|26972|11652|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,753|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,754|[WARNING]|26972|11652|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,755|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,761|[WARNING]|26972|11948|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,761|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,761|[WARNING]|26972|11948|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,761|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,771|[WARNING]|26972|2976|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,774|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,778|[WARNING]|26972|2976|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,783|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,810|[WARNING]|26972|25580|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,810|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,840|[WARNING]|26972|25580|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:41,871|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,084|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,084|[WARNING]|26972|25104|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,086|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,088|[WARNING]|26972|25104|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,094|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,094|[WARNING]|26972|2976|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,096|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,097|[WARNING]|26972|2976|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,104|[WARNING]|26972|11652|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,109|[WARNING]|26972|11652|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,127|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,129|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,139|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,141|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,154|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,159|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,254|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,254|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,272|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,273|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,280|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,281|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,290|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,290|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,290|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,290|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,308|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,308|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,308|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,308|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,325|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:42,325|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:43,420|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:43,436|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:44,385|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:44,385|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:44,385|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:44,385|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:15:45,534|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# Pipeline github_pipeline load step completed in 4.26 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_db
# The duckdb destination used duckdb:///c:\Users\HP\OneDrive\Desktop\Data Engg\dlt\github_pipeline.duckdb location to store data
# Load package 1740305706.5711625 is LOADED and contains no failed jobs

# %% [markdown]
# ### Exercise 2: Run pipeline with dlt.secrets.value
# Question: Who has id=17202864 in the stargazers table? Use sql_client.

# %%
with pipeline.sql_client() as client:
    with client.execute_query("SELECT * FROM github_stargazers WHERE id = 17202864") as cursor:
        print(cursor.fetchall())
# Out:
# 2025-02-23 11:20:14,773|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db' to 'github_db which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# 2025-02-23 11:20:14,773|[WARNING]|26972|1488|dlt|client.py|_normalize_identifier:238|Due to normalization dataset name got changed from 'github.db_staging' to 'github_db_staging which will be used to create db schemas or folders. `dataset_name` field in the pipeline instance will not be changed. We suggest that you use dataset names that do not need to be normalized or disable dataset name normalization via `enable_dataset_name_normalization` on destination configuration.
# [('rudolfix', 17202864, 'MDQ6VXNlcjE3MjAyODY0', 'https://avatars.githubusercontent.com/u/17202864?v=4', '', 'https://api.github.com/users/rudolfix', 'https://github.com/rudolfix', 'https://api.github.com/users/rudolfix/followers', 'https://api.github.com/users/rudolfix/following{/other_user}', 'https://api.github.com/users/rudolfix/gists{/gist_id}', 'https://api.github.com/users/rudolfix/starred{/owner}{/repo}', 'https://api.github.com/users/rudolfix/subscriptions', 'https://api.github.com/users/rudolfix/orgs', 'https://api.github.com/users/rudolfix/repos', 'https://api.github.com/users/rudolfix/events{/privacy}', 'https://api.github.com/users/rudolfix/received_events', 'User', 'public', False, '1740305706.5711625', 'pnAFJfN2P9fUQA')]
